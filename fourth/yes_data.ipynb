# %%
import pandas as pd

# %%
yes_df = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\yes24.csv', encoding='cp949')

# %%
yes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3400 non-null   int64
#  1   raanking   3400 non-null   int64
#  2   title      3400 non-null   object
#  3   writer     3400 non-null   object
#  4   press      3400 non-null   object
#  5   kategorie  3400 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 159.5+ KB

# %%
yes_df.rename(columns={'raanking': 'Ranking', 'data' : 'Data', 'title' : 'Title', 
                       'writer' : 'Writer', 'press' : 'Press', 'kategorie' : 'Category'}, inplace=True)

yes_df.iloc[]
# Out:
#         date  Ranking                                              Title  \
# 0     202402        1                                       마흔에 읽는 쇼펜하우어
# 1     202402        2                              나는 메트로폴리탄 미술관의 경비원입니다
# 2     202402        3                                           세이노의 가르침
# 3     202402        4                                      아이는 무엇으로 자라는가
# 4     202402        5                                         이처럼 사소한 것들
# ...      ...      ...                                                ...
# 3395  202203      196                                            열혈강호 85
# 3396  202203      197                                         박시백의 고려사 1
# 3397  202203      198                                      나는 나답게 살기로 했다
# 3398  202203      199                           읽으면서 바로 써먹는 어린이 한국사 퀴즈 1
# 3399  202203      200  2021·2022 큰별쌤 최태성의 별★별 한국사 7일의 기적 한국사능력검정시험 심화...
#
#                    Writer    Press  Category
# 0                   강용수 저     유노북스        인문
# ...
