# %%
import pandas as pd

# %%
a2303 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2303.csv')
a2304 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2304.csv')
a2305 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2305.csv')
a2306 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2306.csv')
a2307 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2307.csv')
a2308 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2308.csv')
a2309 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2309.csv')
a2310 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2310.csv')
a2311 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2311.csv')
a2312 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2312.csv')
a2401 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2401.csv')
a2402 = pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a2402.csv')

# %%
a2303
# Out:
#    Category                            Title                  Author  \
# 0      국내도서        세이노의 가르침 (70만 부 기념 빨간 표지)           세이노(SayNo) 지음
# 1      국내도서             우리 아기 오감발달 동물농장 사운드북  샘 태플린 지음, 페데리카 아이오사 그림
# 2      국내도서                       김미경의 마흔 수업                  김미경 지음
# 3      국내도서                         스즈메의 문단속      신카이 마코토 지음, 민경욱 옮김
# 4      국내도서  클래식 뮤지컬 차이콥스키의 발레곡 호두까기 인형 사운드북   피오나 와트 지음, 올가 데미도바 그림
# ..      ...                              ...                     ...
# 94     국내도서                세상은 실제로 어떻게 돌아가는가      바츨라프 스밀 지음, 강주헌 옮김
# 95     국내도서                      작가는 어떻게 읽는가       조지 손더스 지음, 정영목 옮김
# 96     국내도서             지적 대화를 위한 넓고 얕은 지식 1                  채사장 지음
# 97     국내도서         돈의 속성 (300쇄 리커버 에디션, 양장)                  김승호 지음
# 98     국내도서                               방주       유키 하루오 지음, 김은모 옮김
#
#       Publisher  Date_of_publication Sub_category
# 0           데이원             20230302         자기계발
# ...

# %%
#a2303 100위 추가 - 행 추가
new_row = {'Title': '이토록 평범한 미래', 'Category': '국내도서', 'Author' : '김연수 지음', 
           'Publisher' : '문학동네', 'Date_of_publication' : 20221007, 'Sub_category' : '소설/희곡'}
# 새로운 행을 포함하는 데이터프레임 생성
new_row_df = pd.DataFrame.from_dict(new_row, orient='index').T

# 새로운 행 추가
a2303 = pd.concat([a2303, new_row_df], ignore_index=True)

a2303

# %%
#위에서 2번 돌려서 1개 빼기
a2303 = a2303.drop(a2303.index[-1])
a2303
# Out:
#    Category                            Title                  Author  \
# 0      국내도서        세이노의 가르침 (70만 부 기념 빨간 표지)           세이노(SayNo) 지음
# 1      국내도서             우리 아기 오감발달 동물농장 사운드북  샘 태플린 지음, 페데리카 아이오사 그림
# 2      국내도서                       김미경의 마흔 수업                  김미경 지음
# 3      국내도서                         스즈메의 문단속      신카이 마코토 지음, 민경욱 옮김
# 4      국내도서  클래식 뮤지컬 차이콥스키의 발레곡 호두까기 인형 사운드북   피오나 와트 지음, 올가 데미도바 그림
# ..      ...                              ...                     ...
# 95     국내도서                      작가는 어떻게 읽는가       조지 손더스 지음, 정영목 옮김
# 96     국내도서             지적 대화를 위한 넓고 얕은 지식 1                  채사장 지음
# 97     국내도서         돈의 속성 (300쇄 리커버 에디션, 양장)                  김승호 지음
# 98     국내도서                               방주       유키 하루오 지음, 김은모 옮김
# 99     국내도서                       이토록 평범한 미래                  김연수 지음
#
#       Publisher Date_of_publication Sub_category
# 0           데이원            20230302         자기계발
# ...

# %%
a2402.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             100 non-null    object
#  1   Title                100 non-null    object
#  2   Author               100 non-null    object
#  3   Publisher            100 non-null    object
#  4   Date_of_publication  100 non-null    int64
#  5   Sub_category         100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
aladin_df= pd.concat([a2303, a2304, a2305, a2306, a2307, a2308, a2309, a2310, a2311, a2312,
                  a2401, a2402], axis=0)
aladin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             1100 non-null   object
#  1   Title                1200 non-null   object
#  2   Author               1100 non-null   object
#  3   Publisher            1200 non-null   object
#  4   Date_of_publication  1000 non-null   object
#  5   Sub_category         1100 non-null   object
#  6   Date_of_pulication   100 non-null    float64
#  7   Caategory            100 non-null    object
#  8   Date_of_Publication  100 non-null    float64
#  9   Sub-category         100 non-null    object
#  10  Ahthor               100 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 112.5+ KB

# %%
#뒤에 쓸모없는 칼럼 지우기
aladin_data = aladin_df.drop(aladin_df.columns[-5:], axis=1)
aladin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             1100 non-null   object
#  1   Title                1200 non-null   object
#  2   Author               1100 non-null   object
#  3   Publisher            1200 non-null   object
#  4   Date_of_publication  1000 non-null   object
#  5   Sub_category         1100 non-null   object
# dtypes: object(6)
# memory usage: 65.6+ KB

# %%
aladin_data.iloc[634:649, :]
# Out:
#    Category                                          Title  \
# 34     국내도서                                  하늘과 바람과 별과 인간
# 35     국내도서  ETS 토익 정기시험 기출문제집 1000 Vol. 3 Listening (리스닝)
# 36     국내도서                                  익명의 독서 중독자들 2
# 37     국내도서                                    푸른 사자 와니니 6
# 38     국내도서                                          결혼·여름
# 39     국내도서                                  김재우의 영어회화 100
# 40     국내도서                            해커스 토익 기출 VOCA (보카)
# 41     국내도서                                         단 한 사람
# 42     국내도서  2023 큰별쌤 최태성의 별★별한국사 한국사능력검정시험 심화(1, 2, 3급) 상
# 43     국내도서                           흔한남매 이상한 나라의 고전 읽기 4
# 44     국내도서                                         집착의 법칙
# 45     국내도서                                 EBS 다큐프라임 자본주의
# 46     국내도서                                      향수가 된 식물들
# 47     국내도서                                    말리의 일곱 개의 달
# 48     국내도서                                설민석의 한국사 대모험 26
#
# ...

# %%
aladin= pd.read_csv(r'C:\Users\utw09\Desktop\정노을\본캠 프로젝트\fourth\a.csv')
